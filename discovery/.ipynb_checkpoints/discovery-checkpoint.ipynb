# %% [markdown]
# ![apple-trees.jpg](attachment:grafik.png)
#
# # Plant Pathology 2020 Challenge: Data Discovery
#
# In this challenge, the goal is to classify images of leaves into healthy ones and ones that have a one or more diseases.

# %% [markdown]
# ## Structure of Raw Data

# %%
# Python libraries
import os

# External modules
import pandas as pd


raw_data_path = os.path.join('..', 'data', 'raw-data')
print(os.listdir(raw_data_path))
print()

train_data = pd.read_csv(os.path.join(raw_data_path, 'train.csv'))
test_data = pd.read_csv(os.path.join(raw_data_path, 'test.csv'))
submission = pd.read_csv(os.path.join(raw_data_path, 'sample_submission.csv'))

print('Train data sample:', train_data.shape)
display(train_data.sample(15))
print('Test data sample:', test_data.shape)
display(test_data.sample(15))
print('Sample submission:', submission.shape)
display(submission.sample(15))
# Out:
# ['images', 'sample_submission.csv', 'test.csv', 'train.csv']
#
# Train data sample: (1821, 5)
#         image_id  healthy  multiple_diseases  rust  scab
# 1462  Train_1462        0                  0     1     0
# 925    Train_925        0                  0     1     0
# 1769  Train_1769        0                  0     0     1
# 1713  Train_1713        0                  0     0     1
# 1372  Train_1372        1                  0     0     0
# 37      Train_37        0                  0     1     0
# 372    Train_372        0                  0     0     1
# 712    Train_712        0                  0     1     0
# 452    Train_452        1                  0     0     0
# 540    Train_540        0                  0     0     1
# 639    Train_639        0                  0     1     0
# 1468  Train_1468        0                  1     0     0
# 1297  Train_1297        1                  0     0     0
# 1251  Train_1251        1                  0     0     0
# ...

# %% [markdown]
# ## A look at a few examples

# %%
# Python libraries
from random import choice

# External modules
import cv2
import matplotlib.pyplot as plt


imgs = os.listdir(os.path.join(raw_data_path, 'images'))
imgs = [ img for img in imgs if 'Train' in img ]
sample_imgs = []
for _ in range(5):
    sample_imgs.append(choice(imgs))

loaded_imgs = []
for img_name in sample_imgs:
    img = cv2.imread(os.path.join(raw_data_path, 'images', img_name))
    loaded_imgs.append(img)
    
sample_imgs = [ img_name[:-4] for img_name in sample_imgs ]
print(sample_imgs)
# Out:
# ['Train_61', 'Train_1139', 'Train_221', 'Train_1413', 'Train_1642']

# %%
display(train_data[train_data['image_id'] == sample_imgs[0]])
plt.imshow(loaded_imgs[0])
# Out:
#     image_id  healthy  multiple_diseases  rust  scab
# 61  Train_61        0                  0     0     1

# %%
display(train_data[train_data['image_id'] == sample_imgs[1]])
plt.imshow(loaded_imgs[1])
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 1139  Train_1139        1                  0     0     0

# %%
display(train_data[train_data['image_id'] == sample_imgs[2]])
plt.imshow(loaded_imgs[2])
# Out:
#       image_id  healthy  multiple_diseases  rust  scab
# 221  Train_221        1                  0     0     0

# %%
display(train_data[train_data['image_id'] == sample_imgs[3]])
plt.imshow(loaded_imgs[3])
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 1413  Train_1413        0                  0     1     0

# %%
display(train_data[train_data['image_id'] == sample_imgs[4]])
plt.imshow(loaded_imgs[4])
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 1642  Train_1642        0                  0     1     0

# %% [markdown]
# ## Distribution of labels

# %%
healthy = train_data[train_data['healthy'] == 1]
print('Sample of healthy leaves:', healthy.shape)
display(healthy.sample(10))
# Out:
# Sample of healthy leaves: (516, 5)
#         image_id  healthy  multiple_diseases  rust  scab
# 815    Train_815        1                  0     0     0
# 443    Train_443        1                  0     0     0
# 427    Train_427        1                  0     0     0
# 219    Train_219        1                  0     0     0
# 921    Train_921        1                  0     0     0
# 1039  Train_1039        1                  0     0     0
# 1092  Train_1092        1                  0     0     0
# 1223  Train_1223        1                  0     0     0
# 1597  Train_1597        1                  0     0     0
# 1598  Train_1598        1                  0     0     0

# %%
mutliple_diseases = train_data[train_data['multiple_diseases'] == 1]
print('Sample of multiply diseased leaves:', mutliple_diseases.shape)
display(mutliple_diseases.sample(10))
# Out:
# Sample of multiply diseased leaves: (91, 5)
#         image_id  healthy  multiple_diseases  rust  scab
# 702    Train_702        0                  1     0     0
# 338    Train_338        0                  1     0     0
# 122    Train_122        0                  1     0     0
# 231    Train_231        0                  1     0     0
# 436    Train_436        0                  1     0     0
# 1369  Train_1369        0                  1     0     0
# 1390  Train_1390        0                  1     0     0
# 1780  Train_1780        0                  1     0     0
# 1173  Train_1173        0                  1     0     0
# 886    Train_886        0                  1     0     0

# %%
rust = train_data[train_data['rust'] == 1]
print('Sample of leaves with rust:', rust.shape)
display(rust.sample(10))
# Out:
# Sample of leaves with rust: (622, 5)
#         image_id  healthy  multiple_diseases  rust  scab
# 945    Train_945        0                  0     1     0
# 726    Train_726        0                  0     1     0
# 1290  Train_1290        0                  0     1     0
# 1322  Train_1322        0                  0     1     0
# 92      Train_92        0                  0     1     0
# 394    Train_394        0                  0     1     0
# 1689  Train_1689        0                  0     1     0
# 314    Train_314        0                  0     1     0
# 60      Train_60        0                  0     1     0
# 387    Train_387        0                  0     1     0

# %%
scab = train_data[train_data['scab'] == 1]
print('Sample of leaves with scab:', scab.shape)
display(scab.sample(10))
# Out:
# Sample of leaves with scab: (592, 5)
#         image_id  healthy  multiple_diseases  rust  scab
# 437    Train_437        0                  0     0     1
# 1382  Train_1382        0                  0     0     1
# 1435  Train_1435        0                  0     0     1
# 780    Train_780        0                  0     0     1
# 628    Train_628        0                  0     0     1
# 565    Train_565        0                  0     0     1
# 0        Train_0        0                  0     0     1
# 1104  Train_1104        0                  0     0     1
# 176    Train_176        0                  0     0     1
# 1074  Train_1074        0                  0     0     1

# %%
total = train_data.shape[0]
summed = len(healthy) + len(mutliple_diseases) + len(rust) + len(scab)

plt.pie([
    len(healthy) / total,
    len(mutliple_diseases) / total,
    len(rust) / total,
    len(scab) / total
], 
    colors = ['green', 'red', 'blue', 'orange'],
    labels = [
        f'Healthy: {len(healthy)}', 
        f'Multiple diseases: {len(mutliple_diseases)}', 
        f'Rust: {len(rust)}', 
        f'Scab: {len(scab)}'
    ]
)

print(summed, total, summed == total)
print('All labels mutually exclude each other, otherwise the sum of all labels would be larger.')
# Out:
# 1821 1821 True
# All labels mutually exclude each other, otherwise the sum of all labels would be larger.
